# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
plt.rcParams['figure.facecolor'] = '1.0'

# %%
mpg = pd.read_csv("Datasets/mpg.csv")

# %%
mpg.head()
# print(mpg.shape)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg[['displ', 'cyl', 'cty', 'hwy']]
# Out:
#      displ  cyl  cty  hwy
# 0      1.8    4   18   29
# 1      1.8    4   21   29
# 2      2.0    4   20   31
# 3      2.0    4   21   30
# 4      2.8    6   16   26
# 5      2.8    6   18   26
# 6      3.1    6   18   27
# 7      1.8    4   18   26
# 8      1.8    4   16   25
# 9      2.0    4   20   28
# 10     2.0    4   19   27
# 11     2.8    6   15   25
# 12     2.8    6   17   25
# 13     3.1    6   17   25
# 14     3.1    6   15   25
# 15     2.8    6   15   24
# 16     3.1    6   17   25
# 17     4.2    8   16   23
# 18     5.3    8   14   20
# 19     5.3    8   11   15
# 20     5.3    8   14   20
# 21     5.7    8   13   17
# 22     6.0    8   12   17
# 23     5.7    8   16   26
# 24     5.7    8   15   23
# 25     6.2    8   16   26
# 26     6.2    8   15   25
# 27     7.0    8   15   24
# 28     5.3    8   14   19
# 29     5.3    8   11   14
# ..     ...  ...  ...  ...
# 204    3.4    6   15   19
# 205    4.0    6   15   18
# 206    4.0    6   16   20
# ...

# %%
# mpg[['manufacturer','year','model','displ','cty','hwy','cyl']].head()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
hehe = mpg.loc[:,['displ','cty','hwy','cyl']]
v_scaled = scaler.fit_transform(hehe)
print(v_scaled[:5])

print(v_scaled.size)
# print(hehe.values[:5])
# print(v_scaled.shape)




Y = distance.pdist(v_scaled, 'euclidean')
oh = distance.squareform(Y)
# print(oh.shape)
print(oh)
noice = pd.DataFrame(oh)


hehe = mpg['manufacturer'] + " " + mpg['model'] +  " " + mpg['year'].astype('str')
# print(hmm.drop_duplicates())


# # noice.columns = hmm
# # noice.set_index(hmm)
# noice.rename(index = hmm,
#             columns = hmm,
#             inplace=True)
# noice.head()
print(Y.max())
print(Y.min())
# Out:
# [[0.03703704 0.34615385 0.53125    0.        ]
#  [0.03703704 0.46153846 0.53125    0.        ]
#  [0.07407407 0.42307692 0.59375    0.        ]
#  [0.07407407 0.46153846 0.5625     0.        ]
#  [0.22222222 0.26923077 0.4375     0.5       ]]
# 936
# [[0.         0.11538462 0.10580714 ... 0.54680872 0.54137105 0.60940911]
#  [0.11538462 0.         0.08220269 ... 0.57451272 0.55353069 0.62735063]
#  [0.10580714 0.08220269 0.         ... 0.56571245 0.54979914 0.61279619]
#  ...
#  [0.54680872 0.57451272 0.56571245 ... 0.         0.07692308 0.15305935]
#  [0.54137105 0.55353069 0.54979914 ... 0.07692308 0.         0.15305935]
#  [0.60940911 0.62735063 0.61279619 ... 0.15305935 0.15305935 0.        ]]
# 1.8264488844536817
# 0.0
# C:\ProgramData\Anaconda3\envs\data-vis\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(Y, 'average')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)

# %%
# fig, ax = plt.subplots(1, figsize = (30,25))

# sns.heatmap(oh, ax = ax,cmap="Blues_r")
mpg['class'].unique().size

iris = sns.load_dataset("iris")








# from sklearn.datasets import load_iris
# iris = load_iris()
# X, y = iris.data, iris.target
# DF = pd.DataFrame(X, index = ["iris_%d" % (i) for i in range(X.shape[0])], columns = iris.feature_names)

# DF_corr = DF.T.corr()
# DF_dism = 1 - DF_corr 

# DF_dism








# species = iris.pop("species")
# # lut = dict(zip(species.unique(), "rbg"))
# lut = dict(zip(species.unique(), sns.color_palette("hls", species.unique().size)))
# row_colors = species.map(lut)

# print(row_colors)
# sns.clustermap(iris, row_colors=row_colors)

# sns.color_palette("hls", 4)
# lut = dict(zip(mpg['class'].unique(), sns.color_palette("hls", mpg['class'].unique().size)))
# print(lut)
# oooh = mpg['class'].map(lut)


# oooh
# print(oooh)

# print(oh)
# # oooh
# # noice = linkage(Y , method='average')
# # sns.clustermap(oh, cmap="Blues_r", row_linkage = noice, row_colors= , col_linkage = noice ,figsize = (30,25)).savefig("hehe")
# sns.clustermap(noice, cmap="Blues_r", figsize = (30,25))
# # fig.savefig("noice")
# Out:
# [4.00133876e-03 2.60889537e-05 1.83154822e-03 ... 4.29187441e-03
#  5.53987884e-03 8.41229000e-05]

# %%
print(hehe)
hmm = pd.DataFrame(v_scaled, columns =['displ','cty','hwy','cyl'])
hmm.rename(index = hehe, inplace = True)
sns.clustermap(hmm, cmap="Blues_r", metric = "euclidean" ,method='average',figsize = (30,25)).savefig("hehe")
hmm
# Out:
# 0                           audi a4 1999
# 1                           audi a4 1999
# 2                           audi a4 2008
# 3                           audi a4 2008
# 4                           audi a4 1999
# 5                           audi a4 1999
# 6                           audi a4 2008
# 7                   audi a4 quattro 1999
# 8                   audi a4 quattro 1999
# 9                   audi a4 quattro 2008
# 10                  audi a4 quattro 2008
# 11                  audi a4 quattro 1999
# 12                  audi a4 quattro 1999
# 13                  audi a4 quattro 2008
# 14                  audi a4 quattro 2008
# 15                  audi a6 quattro 1999
# 16                  audi a6 quattro 2008
# 17                  audi a6 quattro 2008
# 18     chevrolet c1500 suburban 2wd 2008
# 19     chevrolet c1500 suburban 2wd 2008
# 20     chevrolet c1500 suburban 2wd 2008
# 21     chevrolet c1500 suburban 2wd 1999
# 22     chevrolet c1500 suburban 2wd 2008
# ...
